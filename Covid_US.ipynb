# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
 x= [1,2,3]
 y= [1,4,9]
plt.plot(x,y)
plt.title("Demo")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
sample = pd.read_csv('us-counties.csv')
sample
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1       0
# 1       2020-01-22   Snohomish  Washington  53061.0      1       0
# 2       2020-01-23   Snohomish  Washington  53061.0      1       0
# 3       2020-01-24        Cook    Illinois  17031.0      1       0
# 4       2020-01-24   Snohomish  Washington  53061.0      1       0
# ...            ...         ...         ...      ...    ...     ...
# 248888  2020-06-18  Sweetwater     Wyoming  56037.0     44       0
# 248889  2020-06-18       Teton     Wyoming  56039.0    108       1
# 248890  2020-06-18       Uinta     Wyoming  56041.0    116       0
# 248891  2020-06-18    Washakie     Wyoming  56043.0     38       3
# 248892  2020-06-18      Weston     Wyoming  56045.0      1       0
#
# [248893 rows x 6 columns]

# %%
plt.plot(sample.date,sample.state)
plt.figure(figsize=(9,8))

plt.title('Covid rate in USA')
plt.plot(sample.date,sample.cases, label ='cases')
plt.plot(sample.date,sample.deaths, label ='death', color='r')
#plt.plot(sample.date,sample.fips, label ='state')
plt.xlabel("Days")
plt.ylabel("No. of deaths and cases")




plt.legend()
plt.show()

# %%
plt.plot(sample.county,sample.cases)
print(sample.date[1::10])
plt.show()
# Out:
# 1         2020-01-22
# 11        2020-01-26
# 21        2020-01-28
# 31        2020-01-30
# 41        2020-02-01
#              ...
# 248851    2020-06-18
# 248861    2020-06-18
# 248871    2020-06-18
# 248881    2020-06-18
# 248891    2020-06-18
# Name: date, Length: 24890, dtype: object

# %%
plt.hist(sample.Overall)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-1c2c4ecfbecc> in <module>
# ----> 1 plt.hist(sample.Overall)
#       2 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Overall'
